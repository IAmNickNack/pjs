// %%
@file:DependsOn("ch.qos.logback:logback-classic:1.5.23")
io.github.iamnicknack.pjs.sandbox.notebook.NotebookLogger.reconfigureSlf4j()
val notebookLogger = org.slf4j.LoggerFactory.getLogger("notebook")
// Out:
// FORCE-LOADED SLF4J Provider: 2.0.99

// %% [markdown]
// ## Configure the `DeviceFactory`
//
// Although it's possible to create devices directly, it's more convenient to use a `DeviceFactory` to manage the creation of devices.
// Delegating to the device factory provides some benefits:
//
// * It provides a single point of configuration for the application
// * When applied to a `DeviceRegistry`, it provides a single point where the lifecycle of devices can be managed
// * It abstracts device factory configurations
// * It can be swapped out depending on the runtime requirement

// %%
import io.github.iamnicknack.pjs.mock.MockDeviceFactory
import io.github.iamnicknack.pjs.model.device.GenericDeviceFactory

var actualFactory: GenericDeviceFactory = MockDeviceFactory()

// %% [markdown]
// ### Factory decoration by delegation
//
// Devices created via a factory can be decorated with debug logging information, by wrapping the factory instance with a `LoggingDeviceFactory`.
//
// The logging factory simply wraps all `Device` instances with logging decorators which can emit log messages when the device
// is operated on.

// %%
import io.github.iamnicknack.pjs.logging.LoggingDeviceFactory

val deviceFactory: GenericDeviceFactory = LoggingDeviceFactory(actualFactory)

// %% [markdown]
// ### Devices are closeable
//
// Devices implement `AutoCloseable` and as such, own any resources they require to operate. It is generally the responsibility of the caller to close the devices when they are no longer needed:

// %%
import io.github.iamnicknack.pjs.device.gpio.GpioPort
import io.github.iamnicknack.pjs.device.gpio.GpioPortConfig

val config: GpioPortConfig = GpioPortConfig.builder().id("test-port").pin(1).build()
val port: GpioPort = deviceFactory.create(config)
port.write(1)
port.close()
// Out:
// 17:12:05.270 DEBUG [device.GpioPort.test-port           ] Writing port value: ------------------------------1-, 1
// 17:12:05.271 INFO  [device.GpioPort.test-port           ] Closing GPIO port: test-port

// %% [markdown]
// ### Tracking factory (aka Registry)
//
// As an alternative to explicitly closing each device, a tracking factory (or registry) can be used to manage the lifecycle of devices.
//
// On shutdown, this factory is aware of the devices it has created and will close them automatically:

// %%
deviceFactory.asDeviceRegistry().use {
    notebookLogger.info("Creating ports using ${it.javaClass}")
    val port1 = it.create(GpioPortConfig.builder().id("test-port-1").pin(1).build())
    val port2 = it.create(GpioPortConfig.builder().id("test-port-2").pin(2).build())
    port1.write(1)
    port2.write(1)
    port1.write(0)
}
// Out:
// 17:57:39.178 INFO  [notebook                            ] Creating ports using class io.github.iamnicknack.pjs.impl.TrackingDeviceFactory
// 17:57:39.180 INFO  [i.g.i.pjs.impl.TrackingDeviceFactory] Created LoggingGpioPort device with id: test-port-1
// 17:57:39.180 INFO  [i.g.i.pjs.impl.TrackingDeviceFactory] Created LoggingGpioPort device with id: test-port-2
// 17:57:39.180 DEBUG [device.GpioPort.test-port-1         ] Writing port value: ------------------------------1-, 1
// 17:57:39.181 DEBUG [device.GpioPort.test-port-2         ] Writing port value: -----------------------------1--, 1
// 17:57:39.181 DEBUG [device.GpioPort.test-port-1         ] Writing port value: ------------------------------0-, 0
// 17:57:39.181 INFO  [i.g.i.pjs.impl.TrackingDeviceFactory] Closing device: test-port-2, jdk.proxy9.$Proxy39
// 17:57:39.181 INFO  [device.GpioPort.test-port-2         ] Closing GPIO port: test-port-2
// 17:57:39.181 INFO  [i.g.i.pjs.impl.TrackingDeviceFactory] Closing device: test-port-1, jdk.proxy9.$Proxy39
// 17:57:39.181 INFO  [device.GpioPort.test-port-1         ] Closing GPIO port: test-port-1

// %% [markdown]
// In the real world, we'd unlikely choose to wrap a registry in a `use` or `try-with-resources` block. More likely, it would be created at startup and closed at shutdown.
// The use of `use` here is purely to demonstrate the closeable nature of the registry.

// %% [markdown]
// ## Create a pin device
//
// The factory can now be used to create a device. Only device configuration needs to be passed to the factory. If an appropriate provider is configured, the factory will handle the construction of the device.
//
// Here a `GpioPort` is created with an arbitrary `id`, mapped to hardware pin `0` and configured as an output:

// %%
import io.github.iamnicknack.pjs.device.gpio.GpioPort
import io.github.iamnicknack.pjs.device.gpio.GpioPortConfig
import io.github.iamnicknack.pjs.device.gpio.GpioPortMode

val pinConfig: GpioPortConfig = GpioPortConfig.builder()
    .id("test-pin")
    .pin(0)
    .portMode(GpioPortMode.OUTPUT)
    .build()

val pinPort: GpioPort = deviceFactory.create(pinConfig)

// %% [markdown]
// Similarly to how this might be done with the low-level Linux APIs for GPIO `lines` (where a line is mapped to one or many `offset`s which represent the individual pins),
// what's created above is a `Port` which is mapped to only a single pin.
//
// As with all ports, numeric state can be read from and written to the port:

// %%
pinPort.read()
pinPort.write(1)
// Out:
// 17:28:04.420 DEBUG [device.MockGpioPortImpl.test-pin    ] Reading port value: -------------------------------0, 0
// 17:28:04.421 DEBUG [device.MockGpioPortImpl.test-pin    ] Writing port value: -------------------------------1, 1

// %% [markdown]
// However, if all that is required is a pin which can be `high` or `low`, a `Pin` device can be created from the port:

// %%
val pin = pinPort.pin()
pin.high()
pin.low()
// Out:
// 17:28:07.940 DEBUG [device.MockGpioPortImpl.test-pin    ] Writing port value: -------------------------------1, 1
// 17:28:07.941 DEBUG [device.MockGpioPortImpl.test-pin    ] Writing port value: -------------------------------0, 0

// %%
val pinConfig = GpioPortConfig.builder()
    .id("test-pins")
    .pin(14, 15)
    .portMode(GpioPortMode.OUTPUT)
    .build()

val pin = deviceFactory.create(pinConfig).pin(0b10, 0x01)

pin.high()
pin.low()
// Out:
// 17:28:20.092 DEBUG [device.MockGpioPortImpl.test-pins   ] Writing port value: ----------------10--------------, 2
// 17:28:20.093 DEBUG [device.MockGpioPortImpl.test-pins   ] Writing port value: ----------------01--------------, 1

// %% [markdown]
// ## Generic ports
//
// ### Pin mapping
//
// The `GpioPort` used above is an extension of the more generic `Port<Integer>` type.
//
// A `Port<T>` allows values of type `T` to be written to and read from the port. Because `T` is not constrained, it can be anything that is relevant in the context of your application.
//
// Assuming a 3-to-8 decoder is connected to four output pins on the Raspberry Pi is being used to enable various peripheral and is connected as follows:
//
// | Pi Pin | 3-to-8 Input Pin     |
// |--------|----------------------|
// | 14     | A                    |
// | 15     | B                    |
// | 18     | C                    |
// | 23     | Enable - Active High |
//
// and the enable-pin of each device is then connected to a decoder output:
//
// | Peripheral  | Output Pin |
// |-------------|------------|
// | Eeprom      | 0          |
// | MCP23S08    | 1          |
// | 74LS595 (A) | 2          |
// | 74LS595 (B) | 3          |
//
// An `enum` could be created to represent the set of peripherals which could then be used to exclusively enable each
//  device:

// %%
import io.github.iamnicknack.pjs.model.port.Port

/**
 * An enumeration of the enable-pin configurations required by the application
 */
enum class Peripheral(
    val pinMask: Int
) {
    NONE(0),            // active high enable pin (active high enable on bit 3, defaults to 0)
    EEPROM(0 or 8),     // enables output pin 0   (pi output bit 0 + enable on bit 3)
    MCP23S08(1 or 8),   // enables output pin 1   (pi output bit 1 + enable on bit 3)
    SHIFT_A(2 or 8),    // enables output pin 2   (pi output bit 0+1 + enable on bit 3)
    SHIFT_B(3 or 8);    // enables output pin 3   (pi output bit 0+1 + enable on bit 3)

    companion object {
        public fun of(value: Int): Peripheral = when (value) {
            NONE.pinMask -> NONE
            EEPROM.pinMask -> EEPROM
            MCP23S08.pinMask -> MCP23S08
            SHIFT_A.pinMask -> SHIFT_A
            SHIFT_B.pinMask -> SHIFT_B
            else -> error("Failed to map value $value to peripheral")
        }
    }
}

/**
 * A [GpioPortConfig] for the pins requried to control the decoder
 */
val portConfig = GpioPortConfig.builder()
    .id("3-to-8-enable-port")
    .pin(14, 15, 18, 23)
    .portMode(GpioPortMode.OUTPUT)
    .build()

/**
 * A [GpioPort] which can read and write values of the [Peripheral] enumeration
 */
val decoderPort: Port<Peripheral> = deviceFactory.create(portConfig)
    .mapped(Peripheral::of, Peripheral::pinMask)

/**
 * A [Pin] which, when low, outputs [Peripheral.MCP23S08.pinMask]
 */
val mcpEnablePin = decoderPort.pin(Peripheral.NONE, Peripheral.MCP23S08)
/**
 * A [Pin] which, when low, outputs [Peripheral.SHIFT_A.pinMask]
 */
val shiftAEnablePin = decoderPort.pin(Peripheral.NONE, Peripheral.SHIFT_A)
/**
 * A [Pin] which, when low, outputs [Peripheral.SHIFT_B.pinMask]
 */
val shiftBEnablePin = decoderPort.pin(Peripheral.NONE, Peripheral.SHIFT_B)
/**
 * A [Pin] which, when low, outputs [Peripheral.EEPROM.pinMask]
 */
val eepromEnablePin = decoderPort.pin(Peripheral.NONE, Peripheral.EEPROM)

// %% [markdown]
// In application code, it's now possible to have `Pin` devices that can be used to enable and disable up to eight peripherals using only four GPIOs:

// %%
assert(decoderPort.read() == Peripheral.NONE)               // read the current port value (should be `NONE`)

mcpEnablePin.low()                                          // enable the mcp23s08
assert(decoderPort.read() == Peripheral.MCP23S08)
shiftAEnablePin.low()                                       // enable the shift register
assert(decoderPort.read() == Peripheral.SHIFT_A)
shiftBEnablePin.low()                                       // enable the shift register
assert(decoderPort.read() == Peripheral.SHIFT_B)
eepromEnablePin.low()                                       // enable the eeprom
assert(decoderPort.read() == Peripheral.EEPROM)

decoderPort.write(Peripheral.NONE)                          // disable all the peripherals
assert(decoderPort.read() == Peripheral.NONE)
// Out:
// 17:28:48.147 DEBUG [d.M.3-to-8-enable-port              ] Reading port value: --------0----0--00--------------, 0
// 17:28:48.147 DEBUG [d.M.3-to-8-enable-port              ] Writing port value: --------1----0--01--------------, 9
// 17:28:48.148 DEBUG [d.M.3-to-8-enable-port              ] Reading port value: --------1----0--01--------------, 9
// 17:28:48.148 DEBUG [d.M.3-to-8-enable-port              ] Writing port value: --------1----0--10--------------, 10
// 17:28:48.148 DEBUG [d.M.3-to-8-enable-port              ] Reading port value: --------1----0--10--------------, 10
// 17:28:48.148 DEBUG [d.M.3-to-8-enable-port              ] Writing port value: --------1----0--11--------------, 11
// 17:28:48.149 DEBUG [d.M.3-to-8-enable-port              ] Reading port value: --------1----0--11--------------, 11
// 17:28:48.149 DEBUG [d.M.3-to-8-enable-port              ] Writing port value: --------1----0--00--------------, 8
// 17:28:48.149 DEBUG [d.M.3-to-8-enable-port              ] Reading port value: --------1----0--00--------------, 8
// 17:28:48.149 DEBUG [d.M.3-to-8-enable-port              ] Writing port value: --------0----0--00--------------, 0
// 17:28:48.149 DEBUG [d.M.3-to-8-enable-port              ] Reading port value: --------0----0--00--------------, 0

// %% [markdown]
// ### Custom ports
//
// Many enable pins could be used in conjunction with multiple SPI devices when there are more devices to control than hardware chip-selects available.
//
// However, controlling chip-select for a device might not be considered "business logic". For example, it might not be desirable for application code to
// have to explicitly enable and disable a device every time a value is written to it. E.g.:

// %%
import io.github.iamnicknack.pjs.device.spi.SpiConfig

var spi = deviceFactory.create(SpiConfig.builder().id("test-spi").build())

mcpEnablePin.low()
spi.write(0x01)
mcpEnablePin.high()
// Out:
// 17:28:57.698 DEBUG [d.M.3-to-8-enable-port              ] Writing port value: --------1----0--01--------------, 9
// 17:28:57.699 DEBUG [device.MockSpiImpl.test-spi         ] Sending : 1 bytes: [01]
// 17:28:57.699 DEBUG [device.MockSpiImpl.test-spi         ] Received: 1 bytes: [00]
// 17:28:57.699 DEBUG [d.M.3-to-8-enable-port              ] Writing port value: --------0----0--00--------------, 0

// %% [markdown]
// It's likely preferable for application code to be dependent only on a generic `Port<Int>`.
//
// To abstract this type of requirement, it's possible to create a custom port implementation to do this:

// %%
import io.github.iamnicknack.pjs.model.pin.Pin
import io.github.iamnicknack.pjs.model.port.Port

/**
 * @param port a port which requires chip-enable
 * @param pin the enable pin
 */
class EnablePort(
    private val port: Port<Int>,
    private val enablePin: Pin
) : Port<Int> {

    override fun read(): Int = enablePin.activeLow { port.read() }

    override fun write(value: Int?) = enablePin.activeLow { port.write(value) }

    private fun <T> Pin.activeLow(block: () -> T): T {
        try {
            low()
            return block()
        } finally {
            high()
        }
    }
}

// %% [markdown]
// The mechanics of writing to the device are then taken care of, so application code can simply be dependent on a `Port<Int>`:

// %%
/**
 * An useable port which does not require application code to explicitly control
 * the chip-enable signal
 */
val enabledSpiPort: Port<Int> = EnablePort(spi, mcpEnablePin)

enabledSpiPort.write(123)
// Out:
// 17:29:11.140 DEBUG [d.M.3-to-8-enable-port              ] Writing port value: --------1----0--01--------------, 9
// 17:29:11.141 DEBUG [device.MockSpiImpl.test-spi         ] Sending : 1 bytes: [7B]
// 17:29:11.141 DEBUG [device.MockSpiImpl.test-spi         ] Received: 1 bytes: [00]
// 17:29:11.141 DEBUG [d.M.3-to-8-enable-port              ] Writing port value: --------0----0--00--------------, 0
